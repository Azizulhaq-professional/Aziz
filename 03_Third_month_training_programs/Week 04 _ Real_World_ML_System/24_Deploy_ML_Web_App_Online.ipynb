# %% [markdown]
# ## Topic: Deploy ML Web App Online (Render)
# ### Goal of Today
#
# By the end of this session, We will:
#
# - Deploy your ML app online
# - Get a public URL
# - Share your project professionally
# - Build portfolio-ready project

# %% [markdown]
# ### 1. What is Deployment (Cloud)?
#
# 👉 Hosting your app on internet:
# ```
# Local App → Cloud Server → Public URL
# ```
# 💡 Example:
# ```
# http://your-app.onrender.com
# ```
# ### Tools You Will Use
# - Render
# - GitHub
# - Flask app

# %% [markdown]
# ### 📦 2. Final Project Structure
# ```
# ml_web_app/
# │── app.py
# │── final_pipeline_model.pkl
# │── requirements.txt
# │── templates/
# │     └── index.html
#
# ```

# %% [markdown]
# ### 📝 3. Step 1: Create requirements.txt
#
# 👉 This tells server what to install
# ```
# flask
# scikit-learn
# pandas
# joblib
# gunicorn
# ```

# %% [markdown]
# ### ⚙️ 4. Step 2: Update app.py for Deployment
# ```
# import os
#
# if __name__ == "__main__":
#     port = int(os.environ.get("PORT", 5000))
#     app.run(host="0.0.0.0", port=port)

# %% [markdown]
# ### 📂 5. Step 3: Push to GitHub
# ```
# git init
# git add .
# git commit -m "ML Web App"
# git branch -M main
# git remote add origin YOUR_REPO_LINK
# git push -u origin main
# ```

# %% [markdown]
# ### ☁️ 6. Step 4: Deploy on Render
#
# Steps:
# - Go to Render
# - Click New Web Service
# - Connect your **GitHub repo
# - Fill settings:
#
# ⚙️ Settings:
# | Option        | Value                             |
# | ------------- | --------------------------------- |
# | Build Command | `pip install -r requirements.txt` |
# | Start Command | `gunicorn app:app`                |

# %% [markdown]
# ###  7. Step 5: Get Live URL
#
# 👉 After deployment:
# ```
# https://your-app-name.onrender.com
# ```
# ###  8. What You Just Did
#
# 👉 You converted:
# ```
# Local ML Project → Live Web Application
# ```
# ### 9. Real-World Impact
#
# Now you can:
#
# - Share project link in CV
# - Show in interviews
# - Demonstrate real skills
#
# ### 10. Common Issues
# | Problem           | Solution                 |
# | ----------------- | ------------------------ |
# | App not starting  | Check logs               |
# | Model not loading | Ensure file path correct |
# | Error 500         | Debug code               |

# %% [markdown]
# ### 11. Practice Tasks
# #### Task 1:
#
# Deploy your app successfully
#
# #### Task 2:
#
# Share your URL with a friend
#
# #### Task 3:
#
# Update README with live link
#
# ### 12. Master Concept
# ```
# ML + Deployment = Real Product
# ```
